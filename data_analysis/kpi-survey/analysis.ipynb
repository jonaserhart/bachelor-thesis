# %% [markdown]
# # Data analysis: SCRUM KPIs

# %% [markdown]
# ## Data import

# %%
import pandas as pd
import re
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Clean data

# %%
# Rename columns for display
def extract_KPI_name(s):
    match = re.search(r'\[(.*?)\]', s)
    return match.group(0) if match else None

df = pd.read_csv('./survey-results.csv');
experience_column = 'How many years of expirience do you have with SCRUM?'
role_columns = [col for col in df.columns if 'Which SCRUM roles have you primarily taken on?' in col and not 'Other' in col]
other_role_column = [col for col in df.columns if 'Which SCRUM roles have you primarily taken on?' in col and 'Other' in col][0]
kpi_columns = [col for col in df.columns if 'How helpful do you find the following KPIs for SCRUM purposes?' in col and 'Scale 1' in col]
use_kpi_columns = [col for col in df.columns if 'How helpful do you find the following KPIs for SCRUM purposes?' in col and 'Scale 2' in col]

# Only people that have experience with SCRUM are relevant to this survey
df = df[(df['Do you have experience with SCRUM?'] == 'Yes')]

yes_no_replacement = {'Yes': 1, 'No' : 0}

# Clean and replace everything with numerical numbers that is relevant for aggregation computations
df['Do you have experience with SCRUM?'] = df['Do you have experience with SCRUM?'].map({'Yes': 1})
df[role_columns] = df[role_columns].replace(yes_no_replacement)
df[kpi_columns] = df[kpi_columns].replace({'1 - Not helpful at all': 1, '5 - Very helpful' : 5})
df[use_kpi_columns] = df[use_kpi_columns].replace(yes_no_replacement)

# %%
# Correlations

rename_dict = {col: extract_KPI_name(col) for col in kpi_columns}
corr_df = df.copy()
corr_matr = corr_df[[*role_columns, *kpi_columns]].corr()

threshold = 0.75

high_correlation = (corr_matr.where(np.triu(np.ones(corr_matr.shape), k=1).astype(bool))
                    .stack()
                    .reset_index())

high_correlation.columns = ['Variable 1', 'Variable 2', 'Correlation Coefficient']

high_correlation = high_correlation[abs(high_correlation['Correlation Coefficient']) > threshold]

for index, row in high_correlation.iterrows():
    print(f"Variable 1: {row['Variable 1']}, Variable 2: {row['Variable 2']}, Correlation: {row['Correlation Coefficient']}\n")

corr_matr
# Out:
# Variable 1: How helpful do you find the following KPIs for SCRUM purposes? [Number of planned Tickets][Scale 1], Variable 2: How helpful do you find the following KPIs for SCRUM purposes? [Number of done Tickets][Scale 1], Correlation: 0.9056263923284888
#
# Variable 1: How helpful do you find the following KPIs for SCRUM purposes? [Blocker Tickets (Number of 'emergency' tickets that got added during a Sprint)][Scale 1], Variable 2: How helpful do you find the following KPIs for SCRUM purposes? [Blocker Tickets done (Number of 'emergency' tickets that got done in the Sprint)][Scale 1], Correlation: 0.7600239746492246
#                                                     Which SCRUM roles have you primarily taken on? [Product Owner]  \
# Which SCRUM roles have you primarily taken on? ...                                           1.000000
# Which SCRUM roles have you primarily taken on? ...                                          -0.576195
# Which SCRUM roles have you primarily taken on? ...                                           0.070014
# How helpful do you find the following KPIs for ...                                           0.191182
# How helpful do you find the following KPIs for ...                                          -0.079120
# How helpful do you find the following KPIs for ...                                          -0.112473
# How helpful do you find the following KPIs for ...                                          -0.027253
# How helpful do you find the following KPIs for ...                                          -0.021499
# How helpful do you find the following KPIs for ...                                          -0.014754
# How helpful do you find the following KPIs for ...                                           0.048328
# How helpful do you find the following KPIs for ...                                          -0.146377
# How helpful do you find the following KPIs for ...                                          -0.124423
# How helpful do you find the following KPIs for ...                                          -0.083272
# How helpful do you find the following KPIs for ...                                          -0.059923
# How helpful do you find the following KPIs for ...                                           0.225569
#
#                                                     Which SCRUM roles have you primarily taken on? [SCRUM team member]  \
# Which SCRUM roles have you primarily taken on? ...                                          -0.576195
# Which SCRUM roles have you primarily taken on? ...                                           1.000000
# Which SCRUM roles have you primarily taken on? ...                                          -0.233955
# How helpful do you find the following KPIs for ...                                          -0.189558
# How helpful do you find the following KPIs for ...                                          -0.136433
# How helpful do you find the following KPIs for ...                                          -0.165809
# How helpful do you find the following KPIs for ...                                          -0.171420
# How helpful do you find the following KPIs for ...                                          -0.011973
# How helpful do you find the following KPIs for ...                                          -0.040782
# How helpful do you find the following KPIs for ...                                          -0.131938
# How helpful do you find the following KPIs for ...                                           0.009398
# How helpful do you find the following KPIs for ...                                           0.077677
# How helpful do you find the following KPIs for ...                                           0.012175
# How helpful do you find the following KPIs for ...                                          -0.034690
# How helpful do you find the following KPIs for ...                                          -0.170421
#
#                                                     Which SCRUM roles have you primarily taken on? [SCRUM master]  \
# Which SCRUM roles have you primarily taken on? ...                                           0.070014
# Which SCRUM roles have you primarily taken on? ...                                          -0.233955
# Which SCRUM roles have you primarily taken on? ...                                           1.000000
# How helpful do you find the following KPIs for ...                                          -0.018124
# How helpful do you find the following KPIs for ...                                          -0.087323
# How helpful do you find the following KPIs for ...                                          -0.120483
# How helpful do you find the following KPIs for ...                                          -0.077850
# How helpful do you find the following KPIs for ...                                          -0.092120
# How helpful do you find the following KPIs for ...                                          -0.118534
# How helpful do you find the following KPIs for ...                                           0.076696
# How helpful do you find the following KPIs for ...                                          -0.215372
# How helpful do you find the following KPIs for ...                                          -0.134122
# How helpful do you find the following KPIs for ...                                          -0.122868
# How helpful do you find the following KPIs for ...                                          -0.363450
# How helpful do you find the following KPIs for ...                                          -0.047225
#
#                                                     How helpful do you find the following KPIs for SCRUM purposes? [Capacity (How many Story Points can a Team theoretically do in a Sprint?)][Scale 1]  \
# Which SCRUM roles have you primarily taken on? ...                                           0.191182
# Which SCRUM roles have you primarily taken on? ...                                          -0.189558
# Which SCRUM roles have you primarily taken on? ...                                          -0.018124
# How helpful do you find the following KPIs for ...                                           1.000000
# How helpful do you find the following KPIs for ...                                          -0.020791
# How helpful do you find the following KPIs for ...                                           0.046098
# How helpful do you find the following KPIs for ...                                           0.698408
# How helpful do you find the following KPIs for ...                                           0.379978
# How helpful do you find the following KPIs for ...                                           0.653233
# How helpful do you find the following KPIs for ...                                           0.639410
# How helpful do you find the following KPIs for ...                                           0.146296
# How helpful do you find the following KPIs for ...                                           0.076637
# How helpful do you find the following KPIs for ...                                           0.142517
# How helpful do you find the following KPIs for ...                                           0.351664
# How helpful do you find the following KPIs for ...                                           0.107144
#
#                                                     How helpful do you find the following KPIs for SCRUM purposes? [Number of planned Tickets][Scale 1]  \
# Which SCRUM roles have you primarily taken on? ...                                          -0.079120
# Which SCRUM roles have you primarily taken on? ...                                          -0.136433
# Which SCRUM roles have you primarily taken on? ...                                          -0.087323
# How helpful do you find the following KPIs for ...                                          -0.020791
# How helpful do you find the following KPIs for ...                                           1.000000
# How helpful do you find the following KPIs for ...                                           0.905626
# How helpful do you find the following KPIs for ...                                           0.159955
# How helpful do you find the following KPIs for ...                                          -0.046793
# How helpful do you find the following KPIs for ...                                          -0.053107
# How helpful do you find the following KPIs for ...                                          -0.118189
# How helpful do you find the following KPIs for ...                                           0.420931
# How helpful do you find the following KPIs for ...                                           0.356526
# How helpful do you find the following KPIs for ...                                           0.112342
# How helpful do you find the following KPIs for ...                                           0.143030
# How helpful do you find the following KPIs for ...                                           0.159023
#
#                                                     How helpful do you find the following KPIs for SCRUM purposes? [Number of done Tickets][Scale 1]  \
# Which SCRUM roles have you primarily taken on? ...                                          -0.112473
# Which SCRUM roles have you primarily taken on? ...                                          -0.165809
# Which SCRUM roles have you primarily taken on? ...                                          -0.120483
# How helpful do you find the following KPIs for ...                                           0.046098
# How helpful do you find the following KPIs for ...                                           0.905626
# How helpful do you find the following KPIs for ...                                           1.000000
# How helpful do you find the following KPIs for ...                                           0.234490
# How helpful do you find the following KPIs for ...                                          -0.024664
# How helpful do you find the following KPIs for ...                                           0.042315
# How helpful do you find the following KPIs for ...                                          -0.046203
# How helpful do you find the following KPIs for ...                                           0.390285
# How helpful do you find the following KPIs for ...                                           0.278301
# How helpful do you find the following KPIs for ...                                           0.142114
# How helpful do you find the following KPIs for ...                                           0.122422
# How helpful do you find the following KPIs for ...                                           0.208625
#
#                                                     How helpful do you find the following KPIs for SCRUM purposes? [Commitment (Story Points planned for a Sprint)][Scale 1]  \
# Which SCRUM roles have you primarily taken on? ...                                          -0.027253
# Which SCRUM roles have you primarily taken on? ...                                          -0.171420
# Which SCRUM roles have you primarily taken on? ...                                          -0.077850
# How helpful do you find the following KPIs for ...                                           0.698408
# How helpful do you find the following KPIs for ...                                           0.159955
# How helpful do you find the following KPIs for ...                                           0.234490
# How helpful do you find the following KPIs for ...                                           1.000000
# How helpful do you find the following KPIs for ...                                           0.496032
# How helpful do you find the following KPIs for ...                                           0.638260
# How helpful do you find the following KPIs for ...                                           0.507519
# How helpful do you find the following KPIs for ...                                           0.370094
# How helpful do you find the following KPIs for ...                                           0.204477
# How helpful do you find the following KPIs for ...                                           0.275480
# How helpful do you find the following KPIs for ...                                           0.508846
# How helpful do you find the following KPIs for ...                                           0.147058
#
#                                                     How helpful do you find the following KPIs for SCRUM purposes? [Overplanning ratio (Planned Story Points / Capacity)][Scale 1]  \
# Which SCRUM roles have you primarily taken on? ...                                          -0.021499
# Which SCRUM roles have you primarily taken on? ...                                          -0.011973
# Which SCRUM roles have you primarily taken on? ...                                          -0.092120
# How helpful do you find the following KPIs for ...                                           0.379978
# How helpful do you find the following KPIs for ...                                          -0.046793
# How helpful do you find the following KPIs for ...                                          -0.024664
# How helpful do you find the following KPIs for ...                                           0.496032
# How helpful do you find the following KPIs for ...                                           1.000000
# How helpful do you find the following KPIs for ...                                           0.536532
# How helpful do you find the following KPIs for ...                                           0.694754
# How helpful do you find the following KPIs for ...                                           0.297602
# How helpful do you find the following KPIs for ...                                           0.271417
# How helpful do you find the following KPIs for ...                                           0.581778
# How helpful do you find the following KPIs for ...                                           0.481216
# How helpful do you find the following KPIs for ...                                           0.356621
#
#                                                     How helpful do you find the following KPIs for SCRUM purposes? [Amount of done Story Points][Scale 1]  \
# Which SCRUM roles have you primarily taken on? ...                                          -0.014754
# Which SCRUM roles have you primarily taken on? ...                                          -0.040782
# Which SCRUM roles have you primarily taken on? ...                                          -0.118534
# How helpful do you find the following KPIs for ...                                           0.653233
# How helpful do you find the following KPIs for ...                                          -0.053107
# How helpful do you find the following KPIs for ...                                           0.042315
# How helpful do you find the following KPIs for ...                                           0.638260
# How helpful do you find the following KPIs for ...                                           0.536532
# How helpful do you find the following KPIs for ...                                           1.000000
# How helpful do you find the following KPIs for ...                                           0.575772
# How helpful do you find the following KPIs for ...                                           0.227962
# How helpful do you find the following KPIs for ...                                           0.122547
# How helpful do you find the following KPIs for ...                                           0.234320
# How helpful do you find the following KPIs for ...                                           0.389507
# How helpful do you find the following KPIs for ...                                           0.192811
#
#                                                     How helpful do you find the following KPIs for SCRUM purposes? [Velocity (Planned Story Points / Done Story Points)][Scale 1]  \
# Which SCRUM roles have you primarily taken on? ...                                           0.048328
# Which SCRUM roles have you primarily taken on? ...                                          -0.131938
# Which SCRUM roles have you primarily taken on? ...                                           0.076696
# How helpful do you find the following KPIs for ...                                           0.639410
# How helpful do you find the following KPIs for ...                                          -0.118189
# How helpful do you find the following KPIs for ...                                          -0.046203
# How helpful do you find the following KPIs for ...                                           0.507519
# How helpful do you find the following KPIs for ...                                           0.694754
# How helpful do you find the following KPIs for ...                                           0.575772
# How helpful do you find the following KPIs for ...                                           1.000000
# How helpful do you find the following KPIs for ...                                           0.153096
# How helpful do you find the following KPIs for ...                                           0.186446
# How helpful do you find the following KPIs for ...                                           0.482487
# How helpful do you find the following KPIs for ...                                           0.312474
# How helpful do you find the following KPIs for ...                                           0.257562
#
#                                                     How helpful do you find the following KPIs for SCRUM purposes? [Blocker Tickets (Number of 'emergency' tickets that got added during a Sprint)][Scale 1]  \
# Which SCRUM roles have you primarily taken on? ...                                          -0.146377
# Which SCRUM roles have you primarily taken on? ...                                           0.009398
# Which SCRUM roles have you primarily taken on? ...                                          -0.215372
# How helpful do you find the following KPIs for ...                                           0.146296
# How helpful do you find the following KPIs for ...                                           0.420931
# How helpful do you find the following KPIs for ...                                           0.390285
# How helpful do you find the following KPIs for ...                                           0.370094
# How helpful do you find the following KPIs for ...                                           0.297602
# How helpful do you find the following KPIs for ...                                           0.227962
# How helpful do you find the following KPIs for ...                                           0.153096
# How helpful do you find the following KPIs for ...                                           1.000000
# How helpful do you find the following KPIs for ...                                           0.760024
# How helpful do you find the following KPIs for ...                                           0.544222
# How helpful do you find the following KPIs for ...                                           0.447738
# How helpful do you find the following KPIs for ...                                           0.331037
#
#                                                     How helpful do you find the following KPIs for SCRUM purposes? [Blocker Tickets done (Number of 'emergency' tickets that got done in the Sprint)][Scale 1]  \
# Which SCRUM roles have you primarily taken on? ...                                          -0.124423
# Which SCRUM roles have you primarily taken on? ...                                           0.077677
# Which SCRUM roles have you primarily taken on? ...                                          -0.134122
# How helpful do you find the following KPIs for ...                                           0.076637
# How helpful do you find the following KPIs for ...                                           0.356526
# How helpful do you find the following KPIs for ...                                           0.278301
# How helpful do you find the following KPIs for ...                                           0.204477
# How helpful do you find the following KPIs for ...                                           0.271417
# How helpful do you find the following KPIs for ...                                           0.122547
# How helpful do you find the following KPIs for ...                                           0.186446
# How helpful do you find the following KPIs for ...                                           0.760024
# How helpful do you find the following KPIs for ...                                           1.000000
# How helpful do you find the following KPIs for ...                                           0.552883
# How helpful do you find the following KPIs for ...                                           0.396395
# How helpful do you find the following KPIs for ...                                           0.560959
#
#                                                     How helpful do you find the following KPIs for SCRUM purposes? [Additional Tickets (Tickets that got added unexpectedly during the Sprint)][Scale 1]  \
# Which SCRUM roles have you primarily taken on? ...                                          -0.083272
# Which SCRUM roles have you primarily taken on? ...                                           0.012175
# Which SCRUM roles have you primarily taken on? ...                                          -0.122868
# How helpful do you find the following KPIs for ...                                           0.142517
# How helpful do you find the following KPIs for ...                                           0.112342
# How helpful do you find the following KPIs for ...                                           0.142114
# How helpful do you find the following KPIs for ...                                           0.275480
# How helpful do you find the following KPIs for ...                                           0.581778
# How helpful do you find the following KPIs for ...                                           0.234320
# How helpful do you find the following KPIs for ...                                           0.482487
# How helpful do you find the following KPIs for ...                                           0.544222
# How helpful do you find the following KPIs for ...                                           0.552883
# How helpful do you find the following KPIs for ...                                           1.000000
# How helpful do you find the following KPIs for ...                                           0.425822
# How helpful do you find the following KPIs for ...                                           0.584369
#
#                                                     How helpful do you find the following KPIs for SCRUM purposes? [Open Story points (How many story points are not done at the end of a Sprint and what state are they in?)][Scale 1]  \
# Which SCRUM roles have you primarily taken on? ...                                          -0.059923
# Which SCRUM roles have you primarily taken on? ...                                          -0.034690
# Which SCRUM roles have you primarily taken on? ...                                          -0.363450
# How helpful do you find the following KPIs for ...                                           0.351664
# How helpful do you find the following KPIs for ...                                           0.143030
# How helpful do you find the following KPIs for ...                                           0.122422
# How helpful do you find the following KPIs for ...                                           0.508846
# How helpful do you find the following KPIs for ...                                           0.481216
# How helpful do you find the following KPIs for ...                                           0.389507
# How helpful do you find the following KPIs for ...                                           0.312474
# How helpful do you find the following KPIs for ...                                           0.447738
# How helpful do you find the following KPIs for ...                                           0.396395
# How helpful do you find the following KPIs for ...                                           0.425822
# How helpful do you find the following KPIs for ...                                           1.000000
# How helpful do you find the following KPIs for ...                                           0.393108
#
#                                                     How helpful do you find the following KPIs for SCRUM purposes? [Removed Tickets (Tickets that got removed during a Sprint)][Scale 1]
# Which SCRUM roles have you primarily taken on? ...                                           0.225569
# Which SCRUM roles have you primarily taken on? ...                                          -0.170421
# Which SCRUM roles have you primarily taken on? ...                                          -0.047225
# How helpful do you find the following KPIs for ...                                           0.107144
# How helpful do you find the following KPIs for ...                                           0.159023
# How helpful do you find the following KPIs for ...                                           0.208625
# How helpful do you find the following KPIs for ...                                           0.147058
# How helpful do you find the following KPIs for ...                                           0.356621
# How helpful do you find the following KPIs for ...                                           0.192811
# How helpful do you find the following KPIs for ...                                           0.257562
# How helpful do you find the following KPIs for ...                                           0.331037
# How helpful do you find the following KPIs for ...                                           0.560959
# How helpful do you find the following KPIs for ...                                           0.584369
# How helpful do you find the following KPIs for ...                                           0.393108
# How helpful do you find the following KPIs for ...                                           1.000000

# %% [markdown]
# ## Analyse participant data

# %%
part_data = df.copy()

# %%
# analyse experience question
exp_stats = part_data[experience_column].value_counts()
exp_stats_percentage = part_data[experience_column].value_counts(normalize=True) * 100

print(exp_stats)
print(exp_stats_percentage)
# Out:
# How many years of expirience do you have with SCRUM?
# 4+ years            26
# 2-4 years           13
# 1-2 years            7
# less than 1 year     3
# Name: count, dtype: int64
# How many years of expirience do you have with SCRUM?
# 4+ years            53.061224
# 2-4 years           26.530612
# 1-2 years           14.285714
# less than 1 year     6.122449
# Name: proportion, dtype: float64

# %%
roles_stats = part_data[role_columns].apply(pd.to_numeric, errors='coerce').agg(['mean', 'sum'])

roles_result = roles_stats.T
roles_result['mean'] *= 100
roles_result.columns = ['Percentage', 'Total']
roles_result
# Out:
#                                                     Percentage  Total
# Which SCRUM roles have you primarily taken on? ...   30.612245   15.0
# Which SCRUM roles have you primarily taken on? ...   67.346939   33.0
# Which SCRUM roles have you primarily taken on? ...   28.571429   14.0

# %%
options_other_roles_count = part_data[other_role_column].apply(lambda x: 0 if pd.isna(x) else 1).agg(['sum'])['sum']

print('Amount of other roles provided:', options_other_roles_count)

options = part_data[part_data[other_role_column].notna()][other_role_column].values.tolist()
print('Other roles: ', options)
# Out:
# Amount of other roles provided: 5
# Other roles:  ['Beobachter', 'Developer', 'product manager', 'Trainer pspo1', 'SCRUM-adjacent colleague observing product development process output']

# %% [markdown]
# ## Analyse KPI data

# %% [markdown]
# ### KPIs and ratings
#
# This section will evaluate the surveys part about KPIs and their helpfulness

# %%
kpi_eval = df.copy()

# %% [markdown]
# First the mean, min and max rating of each KPI is computed:

# %%
# Compute table
cleaned_kpi_statistics = kpi_eval[kpi_columns].apply(pd.to_numeric, errors='coerce').agg(['mean', 'min', 'max'])

rename_dict = {col: extract_KPI_name(col) for col in kpi_columns}

cleaned_kpi_statistics.rename(columns=rename_dict, inplace=True)
cleaned_kpi_statistics.T.sort_values(by='mean', ascending=False)
# Out:
#                                                         mean  min  max
# [Capacity (How many Story Points can a Team the...  3.959184  1.0  5.0
# [Amount of done Story Points]                       3.755102  1.0  5.0
# [Commitment (Story Points planned for a Sprint)]    3.714286  1.0  5.0
# [Velocity (Planned Story Points / Done Story Po...  3.714286  1.0  5.0
# [Open Story points (How many story points are n...  3.632653  1.0  5.0
# [Blocker Tickets (Number of 'emergency' tickets...  3.204082  1.0  5.0
# [Overplanning ratio (Planned Story Points / Cap...  3.040816  1.0  5.0
# [Additional Tickets (Tickets that got added une...  2.897959  1.0  5.0
# [Number of done Tickets]                            2.857143  1.0  5.0
# [Number of planned Tickets]                         2.816327  1.0  5.0
# [Blocker Tickets done (Number of 'emergency' ti...  2.816327  1.0  5.0
# [Removed Tickets (Tickets that got removed duri...  2.448980  1.0  5.0

# %% [markdown]
# Secondly it should be computed where the KPI is used by the participants or not

# %%
kpi_use_statistics = kpi_eval[use_kpi_columns].apply(pd.to_numeric, errors='coerce').agg(['mean', 'sum'])

rename_kpis_use_names = {col: extract_KPI_name(col) for col in use_kpi_columns}

kpi_use_statistics.rename(columns=rename_kpis_use_names, inplace=True)

kpi_use_result = kpi_use_statistics.T
kpi_use_result['mean'] *= 100
kpi_use_result.columns = ['Percentage (Yes)', 'Total (Yes)']
kpi_use_result
# Out:
#                                                     Percentage (Yes)  \
# [Capacity (How many Story Points can a Team the...         87.755102
# [Number of planned Tickets]                                59.183673
# [Number of done Tickets]                                   63.265306
# [Commitment (Story Points planned for a Sprint)]           87.755102
# [Overplanning ratio (Planned Story Points / Cap...         53.061224
# [Amount of done Story Points]                              85.714286
# [Velocity (Planned Story Points / Done Story Po...         79.591837
# [Blocker Tickets (Number of 'emergency' tickets...         48.979592
# [Blocker Tickets done (Number of 'emergency' ti...         42.857143
# [Additional Tickets (Tickets that got added une...         51.020408
# [Open Story points (How many story points are n...         71.428571
# [Removed Tickets (Tickets that got removed duri...         36.734694
#
#                                                     Total (Yes)
# [Capacity (How many Story Points can a Team the...         43.0
# [Number of planned Tickets]                                29.0
# [Number of done Tickets]                                   31.0
# [Commitment (Story Points planned for a Sprint)]           43.0
# [Overplanning ratio (Planned Story Points / Cap...         26.0
# [Amount of done Story Points]                              42.0
# [Velocity (Planned Story Points / Done Story Po...         39.0
# [Blocker Tickets (Number of 'emergency' tickets...         24.0
# [Blocker Tickets done (Number of 'emergency' ti...         21.0
# [Additional Tickets (Tickets that got added une...         25.0
# [Open Story points (How many story points are n...         35.0
# [Removed Tickets (Tickets that got removed duri...         18.0
